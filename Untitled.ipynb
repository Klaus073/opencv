# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img=Image.open("jett.jpg")

# %%
imgr=np.asarray(img)
imgr
# Out:
# array([[[ 54,  19,  17],
#         [ 54,  19,  17],
#         [ 54,  19,  17],
#         ...,
#         [  9,  12,  17],
#         [  9,  12,  17],
#         [  9,  12,  17]],
#
#        [[ 54,  19,  17],
#         [ 54,  19,  17],
#         [ 54,  19,  17],
#         ...,
#         [  9,  12,  17],
#         [  9,  12,  17],
#         [  9,  12,  17]],
#
#        [[ 54,  19,  17],
#         [ 54,  19,  17],
#         [ 54,  19,  17],
#         ...,
#         [  9,  13,  16],
#         [  9,  13,  16],
#         [  9,  13,  16]],
#
#        ...,
#
#        [[122,  73,  58],
#         [122,  73,  58],
#         [123,  74,  59],
#         ...,
#         [ 24,   6,   6],
#         [ 24,   6,   6],
#         [ 23,   5,   5]],
#
#        [[122,  73,  58],
#         [122,  73,  58],
#         [122,  73,  58],
#         ...,
#         [ 24,   6,   6],
#         [ 24,   6,   6],
#         [ 23,   5,   5]],
#
#        [[123,  74,  59],
#         [123,  74,  59],
#         [122,  73,  58],
# ...

# %%
imgrr=-1*imgr+256
imgrr
# Out:
# array([[[202, 237, 239],
#         [202, 237, 239],
#         [202, 237, 239],
#         ...,
#         [247, 244, 239],
#         [247, 244, 239],
#         [247, 244, 239]],
#
#        [[202, 237, 239],
#         [202, 237, 239],
#         [202, 237, 239],
#         ...,
#         [247, 244, 239],
#         [247, 244, 239],
#         [247, 244, 239]],
#
#        [[202, 237, 239],
#         [202, 237, 239],
#         [202, 237, 239],
#         ...,
#         [247, 243, 240],
#         [247, 243, 240],
#         [247, 243, 240]],
#
#        ...,
#
#        [[134, 183, 198],
#         [134, 183, 198],
#         [133, 182, 197],
#         ...,
#         [232, 250, 250],
#         [232, 250, 250],
#         [233, 251, 251]],
#
#        [[134, 183, 198],
#         [134, 183, 198],
#         [134, 183, 198],
#         ...,
#         [232, 250, 250],
#         [232, 250, 250],
#         [233, 251, 251]],
#
#        [[133, 182, 197],
#         [133, 182, 197],
#         [134, 183, 198],
# ...

# %%
plt.figure(figsize=(10,10))
plt.imshow(imgrr)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
